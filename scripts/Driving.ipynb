# %%
#!/usr/bin/env python3

import rospy
import time
import jetson.inference
import jetson.utils
import cv2, numpy

import argparse
import sys
import os
from std_msgs.msg import String, Int64
import ipywidgets

parser = argparse.ArgumentParser(description="Locate objects in a live camera stream using an object detection DNN.", 
                                 formatter_class=argparse.RawTextHelpFormatter, epilog=jetson.inference.detectNet.Usage() +
                                 jetson.utils.videoSource.Usage() + jetson.utils.videoOutput.Usage() + jetson.utils.logUsage())

parser.add_argument("input_URI", type=str, default="", nargs='?', help="URI of the input stream")
parser.add_argument("output_URI", type=str, default="", nargs='?', help="URI of the output stream")
parser.add_argument("--network", type=str, default="ssd-mobilenet-v2", help="pre-trained model to load (see below for options)")
parser.add_argument("--overlay", type=str, default="box,labels,conf", help="detection overlay flags (e.g. --overlay=box,labels,conf)\nvalid combinations are:  'box', 'labels', 'conf', 'none'")
parser.add_argument("--threshold", type=float, default=0.5, help="minimum detection threshold to use") 

is_headless = ["--headless"] if sys.argv[0].find('console.py') != -1 else [""]

try:
	opt = parser.parse_known_args()[0]
except:
	print("")
	parser.print_help()
	sys.exit(0)

net = jetson.inference.detectNet(argv=['--model=models/ssd-mobilenet.onnx', '--labels=models/labels.txt', '--input-blob=input_0', '--output-cvg=scores', '--output-bbox=boxes'])
rospy.init_node('detect_control')

pub = rospy.Publisher('/jetbot_motors/cmd_str', String, queue_size=3)
pub2 = rospy.Publisher('cx', Int64, queue_size = 1)
pub3 = rospy.Publisher('/alarm', String, queue_size=1)

camera = jetson.utils.videoSource(argv=["csi://0", "--input-flip=horizontal"])
output = jetson.utils.videoOutput("display://0")

# %%
from IPython.display import display
import ipywidgets

def pre(img):
	image = jetson.utils.cudaToNumpy(img)
	image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
	image = bytes(cv2.imencode('.jpg', image[:, ::-1, :])[1])
	return image

image_w = ipywidgets.Image(format='jpeg')
display(image_w)
# Out:
# Image(value=b'', format='jpeg')

# %%
image_f = ipywidgets.Image(format='jpeg')
display(image_f)
# Out:
# Image(value=b'', format='jpeg')

# %%
image_co = ipywidgets.Image(format='jpeg')
display(image_co)
# Out:
# Image(value=b'', format='jpeg')

# %%
def line_following(frame):
    frame = jetson.utils.cudaToNumpy(frame)
    f_crop = frame[400:720, :]
    f_crop = cv2.cvtColor(f_crop, cv2.COLOR_RGB2BGR)
    hsv = cv2.cvtColor(f_crop, cv2.COLOR_BGR2HSV)
    global cx
    global cy
    image_co.value = bytes(cv2.imencode('.jpg', f_crop[:, ::-1, :])[1])
    lower = numpy.array([22, 93, 0], dtype="uint8")
    upper = numpy.array([45, 255, 255], dtype="uint8")
    mask = cv2.inRange(hsv, lower, upper)
    result = cv2.bitwise_and(f_crop, f_crop, mask=mask)
    
    M = cv2.moments(mask)
    if M['m00'] > 0:
        cx = int(M['m10'] / M['m00'])
        cy = int(M['m01'] / M['m00'])
        cv2.line(result, (cx, 0), (cx, 720), (255, 0, 0), 2)
        cv2.line(result, (0, cy), (1280, cy), (255, 0, 0), 2)
        pub2.publish(cx)
    image_f.value = bytes(cv2.imencode('.jpg', result[:, ::-1, :])[1])
    cv2.imshow('frame', result)

# %%
while True:
	img = camera.Capture()
	detections = net.Detect(img, overlay='NONE')
    
	num = len(detections)
	if num > 0:
		for detection in detections:
			class_name = net.GetClassDesc(detection.ClassID)
			class_conf = 100*detection.Confidence
			class_box = int(detection.Area)
			if class_name == "STOP" and class_box >= 30000:
				pub.publish("stop")
				rospy.loginfo("Stop sign is detected")
			elif class_name == "LEFT" and class_box >= 30000:
				pub.publish("left")
				rospy.loginfo("Left sign is detected")
			elif class_name == "RIGHT"and class_box >= 20000:
				pub.publish("right")
				rospy.loginfo("Right sign is detected")
			elif class_name == "SLOW" or class_name == "CHILD" and class_box >= 50000 and class_conf >= 90:
				pub.publish("slow")
				rospy.loginfo("school zone")
				rospy.sleep(3)
			elif class_name == "POTHOLE" and class_conf >= 80:
				pub3.publish("pothole")
				rospy.loginfo("Pothole is detected")
				line_following(img)
			elif class_name == "CRACK" and class_conf >= 60:
				pub3.publish("crack")
				rospy.loginfo("Crack is detected")
				pub.publish("forward")
			else:
				rospy.loginfo("Confidence: %d" , int(class_conf))
				line_following(img)
	else:
		line_following(img)
		rospy.loginfo("Nothing is detected")
        
	output.Render(img)
	image_w.value = pre(img)
	output.SetStatus("{:s} | Network {:.0f} FPS".format(opt.network, net.GetNetworkFPS()))
	net.PrintProfilerTimes()

	if not camera.IsStreaming() or not output.IsStreaming():
		break
	if cv2.waitKey(1) & 0xFF == ord('q'):
		break
# Out:
# [INFO] [1624187239.349793]: Nothing is detected
# [INFO] [1624187240.316590]: Nothing is detected
# [INFO] [1624187240.911672]: Nothing is detected
# [INFO] [1624187241.338650]: Nothing is detected
# [INFO] [1624187241.607861]: Nothing is detected
# [INFO] [1624187241.870010]: Nothing is detected
# [INFO] [1624187242.183970]: Nothing is detected
# [INFO] [1624187242.699092]: Nothing is detected
# [INFO] [1624187242.982726]: Nothing is detected
# [INFO] [1624187243.262166]: Nothing is detected
# [INFO] [1624187243.508807]: Nothing is detected
# [INFO] [1624187243.756310]: Nothing is detected
# [INFO] [1624187244.128896]: Nothing is detected
# [INFO] [1624187244.442837]: Nothing is detected
# [INFO] [1624187244.721899]: Nothing is detected
# [INFO] [1624187245.013658]: Nothing is detected
# [INFO] [1624187245.276468]: Nothing is detected
# [INFO] [1624187245.556865]: Nothing is detected
# [INFO] [1624187245.908715]: Nothing is detected
# [INFO] [1624187246.208875]: Nothing is detected
# [INFO] [1624187246.485058]: Nothing is detected
# [INFO] [1624187246.819623]: Nothing is detected
# [INFO] [1624187247.101253]: Nothing is detected
# [INFO] [1624187247.409901]: Nothing is detected
# [INFO] [1624187247.770796]: Nothing is detected
# [INFO] [1624187248.027167]: Nothing is detected
# [INFO] [1624187248.276946]: Nothing is detected
# [INFO] [1624187248.549039]: Nothing is detected
# [INFO] [1624187248.801624]: Nothing is detected
# [INFO] [1624187249.146805]: Nothing is detected
# [INFO] [1624187249.482341]: Nothing is detected
# [INFO] [1624187249.734332]: Nothing is detected
# [INFO] [1624187249.999355]: Nothing is detected
# [INFO] [1624187250.245571]: Nothing is detected
# [INFO] [1624187250.503520]: Nothing is detected
# [INFO] [1624187250.840170]: Nothing is detected
# [INFO] [1624187251.190913]: Nothing is detected
# [INFO] [1624187251.424471]: Nothing is detected
# [INFO] [1624187251.694025]: Nothing is detected
# [INFO] [1624187251.997901]: Nothing is detected
# [INFO] [1624187252.291546]: Nothing is detected
# [INFO] [1624187252.593916]: Nothing is detected
# [INFO] [1624187252.947193]: Nothing is detected
# [INFO] [1624187253.191032]: Nothing is detected
# [INFO] [1624187253.462246]: Nothing is detected
# [INFO] [1624187253.696704]: Nothing is detected
# [INFO] [1624187253.977094]: Nothing is detected
# [INFO] [1624187254.301796]: Nothing is detected
# [INFO] [1624187254.632346]: Nothing is detected
# [INFO] [1624187254.888137]: Nothing is detected
# [INFO] [1624187255.139197]: Nothing is detected
# [INFO] [1624187255.398436]: Nothing is detected
# [INFO] [1624187255.680641]: Nothing is detected
# [INFO] [1624187255.982624]: Nothing is detected
# [INFO] [1624187256.320274]: Nothing is detected
# [INFO] [1624187256.577516]: Nothing is detected
# [INFO] [1624187256.868478]: Nothing is detected
# [INFO] [1624187257.197554]: Nothing is detected
# [INFO] [1624187257.478450]: Nothing is detected
# [INFO] [1624187257.827784]: Nothing is detected
# [INFO] [1624187258.101401]: Nothing is detected
# [INFO] [1624187258.366269]: Nothing is detected
# [INFO] [1624187258.665999]: Nothing is detected
# [INFO] [1624187258.894640]: Nothing is detected
# [INFO] [1624187259.160835]: Nothing is detected
# [INFO] [1624187259.492713]: Nothing is detected
# [INFO] [1624187259.795184]: Nothing is detected
# [INFO] [1624187260.042526]: Nothing is detected
# [INFO] [1624187260.300063]: Nothing is detected
# [INFO] [1624187260.562287]: Nothing is detected
# [INFO] [1624187260.856919]: Nothing is detected
# [INFO] [1624187261.200856]: Nothing is detected
# [INFO] [1624187261.515059]: Nothing is detected
# [INFO] [1624187261.768210]: Nothing is detected
# [INFO] [1624187262.039016]: Nothing is detected
# [INFO] [1624187262.299781]: Nothing is detected
# [INFO] [1624187262.584369]: Nothing is detected
# [INFO] [1624187263.022647]: Nothing is detected
# [INFO] [1624187263.303539]: Nothing is detected
# [INFO] [1624187263.562157]: Nothing is detected
# [INFO] [1624187263.815584]: Nothing is detected
# [INFO] [1624187264.057612]: Nothing is detected
# [INFO] [1624187264.405072]: Nothing is detected
# [INFO] [1624187264.746582]: Nothing is detected
# [INFO] [1624187265.031822]: Nothing is detected
# [INFO] [1624187265.317312]: Nothing is detected
# [INFO] [1624187265.589647]: Nothing is detected
# [INFO] [1624187265.895311]: Nothing is detected
# [INFO] [1624187266.245741]: Nothing is detected
# [INFO] [1624187266.571449]: Nothing is detected
# [INFO] [1624187266.838324]: Nothing is detected
# [INFO] [1624187267.177892]: Nothing is detected
# [INFO] [1624187267.427631]: Nothing is detected
# [INFO] [1624187267.780373]: Nothing is detected
# [INFO] [1624187268.160124]: Nothing is detected
# [INFO] [1624187268.410962]: Nothing is detected
# [INFO] [1624187268.671152]: Nothing is detected
# [INFO] [1624187268.933812]: Nothing is detected
# [INFO] [1624187269.218963]: Nothing is detected
# [INFO] [1624187269.519735]: Nothing is detected
# [INFO] [1624187269.839783]: Nothing is detected
# [INFO] [1624187270.094924]: Nothing is detected
# [INFO] [1624187270.377064]: Nothing is detected
# [INFO] [1624187270.641810]: Nothing is detected
# [INFO] [1624187270.921754]: Nothing is detected
# [INFO] [1624187271.236811]: Nothing is detected
# [INFO] [1624187271.572917]: Nothing is detected
# [INFO] [1624187271.827123]: Nothing is detected
# [INFO] [1624187272.091477]: Nothing is detected
# [INFO] [1624187272.382511]: Nothing is detected
# [INFO] [1624187272.665608]: Nothing is detected
# [INFO] [1624187273.097744]: Nothing is detected
# [INFO] [1624187273.351846]: Nothing is detected
# [INFO] [1624187273.615829]: Nothing is detected
# [INFO] [1624187273.858670]: Nothing is detected
# [INFO] [1624187274.113577]: Nothing is detected
# [INFO] [1624187274.432014]: Nothing is detected
# [INFO] [1624187274.774008]: Nothing is detected
# [INFO] [1624187275.044939]: Nothing is detected
# [INFO] [1624187275.337494]: Nothing is detected
# [INFO] [1624187275.620978]: Nothing is detected
# [INFO] [1624187275.930681]: Nothing is detected
# [INFO] [1624187276.248073]: Nothing is detected
# [INFO] [1624187276.556849]: Nothing is detected
# [INFO] [1624187276.820251]: Nothing is detected
# [INFO] [1624187277.092587]: Nothing is detected
# [INFO] [1624187277.432375]: Nothing is detected
# [INFO] [1624187277.806810]: Nothing is detected
# [INFO] [1624187278.148850]: Nothing is detected
# [INFO] [1624187278.425294]: Nothing is detected
# [INFO] [1624187278.675773]: Nothing is detected
# [INFO] [1624187278.939200]: Nothing is detected
# [INFO] [1624187279.176749]: Nothing is detected
# [INFO] [1624187279.471070]: Nothing is detected
# [INFO] [1624187279.827657]: Nothing is detected
# [INFO] [1624187280.069217]: Nothing is detected
# [INFO] [1624187280.350621]: Nothing is detected
# [INFO] [1624187280.604918]: Nothing is detected
# [INFO] [1624187280.855076]: Nothing is detected
# [INFO] [1624187281.152076]: Nothing is detected
# [INFO] [1624187281.526958]: Nothing is detected
# [INFO] [1624187281.755699]: Nothing is detected
# [INFO] [1624187282.008737]: Nothing is detected
# [INFO] [1624187282.272840]: Nothing is detected
# [INFO] [1624187282.542775]: Nothing is detected
# [INFO] [1624187282.928872]: Nothing is detected
# [INFO] [1624187283.261830]: Nothing is detected
# [INFO] [1624187283.519684]: Nothing is detected
# [INFO] [1624187283.763318]: Nothing is detected
# [INFO] [1624187284.031027]: Nothing is detected
# [INFO] [1624187284.301035]: Nothing is detected
# [INFO] [1624187284.600318]: Nothing is detected
# [INFO] [1624187284.924564]: Nothing is detected
# [INFO] [1624187285.168017]: Nothing is detected
# [INFO] [1624187285.428377]: Nothing is detected
# [INFO] [1624187285.686292]: Nothing is detected
# [INFO] [1624187285.970964]: Nothing is detected
# [INFO] [1624187286.275037]: Nothing is detected
# [INFO] [1624187286.583465]: Nothing is detected
# [INFO] [1624187286.858988]: Nothing is detected
# [INFO] [1624187287.105056]: Nothing is detected
# [INFO] [1624187287.361651]: Nothing is detected
# [INFO] [1624187287.708144]: Nothing is detected
# [INFO] [1624187288.064687]: Nothing is detected
# [INFO] [1624187288.360514]: Nothing is detected
# [INFO] [1624187288.641612]: Nothing is detected
# [INFO] [1624187288.898425]: Nothing is detected
# [INFO] [1624187289.124655]: Nothing is detected
# [INFO] [1624187289.421513]: Nothing is detected
# [INFO] [1624187289.796061]: Nothing is detected
# [INFO] [1624187290.070612]: Nothing is detected
# [INFO] [1624187290.313082]: Nothing is detected
# [INFO] [1624187290.579576]: Nothing is detected
# [INFO] [1624187290.813570]: Nothing is detected
# [INFO] [1624187291.116201]: Nothing is detected
# [INFO] [1624187291.478361]: Nothing is detected
# [INFO] [1624187291.726942]: Nothing is detected
# [INFO] [1624187291.989801]: Nothing is detected
# [INFO] [1624187292.245492]: Nothing is detected
# [INFO] [1624187292.508654]: Nothing is detected
# [INFO] [1624187292.848062]: Nothing is detected
# [INFO] [1624187293.222257]: Nothing is detected
# [INFO] [1624187293.501879]: Nothing is detected
# [INFO] [1624187293.734882]: Nothing is detected
# [INFO] [1624187294.014377]: Nothing is detected
# [INFO] [1624187294.260344]: Nothing is detected
# [INFO] [1624187294.562819]: Nothing is detected
# [INFO] [1624187294.925050]: Nothing is detected
# [INFO] [1624187295.174170]: Nothing is detected
# [INFO] [1624187295.449140]: Nothing is detected
# [INFO] [1624187295.745192]: Nothing is detected
# [INFO] [1624187296.034323]: Nothing is detected
# [INFO] [1624187296.365405]: Nothing is detected
# [INFO] [1624187296.662191]: Nothing is detected
# [INFO] [1624187296.921612]: Nothing is detected
# [INFO] [1624187297.188545]: Nothing is detected
# [INFO] [1624187297.485854]: Nothing is detected
# [INFO] [1624187297.801894]: Nothing is detected
# [INFO] [1624187298.108068]: Nothing is detected
# [INFO] [1624187298.425342]: Nothing is detected
# [INFO] [1624187298.668353]: Nothing is detected
# [INFO] [1624187298.946615]: Nothing is detected
# [INFO] [1624187299.197889]: Nothing is detected
# [INFO] [1624187299.491566]: Nothing is detected
# [INFO] [1624187299.850905]: Nothing is detected
# [INFO] [1624187300.115660]: Nothing is detected
# [INFO] [1624187300.370813]: Nothing is detected
# [INFO] [1624187300.624858]: Nothing is detected
# [INFO] [1624187300.890208]: Nothing is detected
# [INFO] [1624187301.161065]: Nothing is detected
# [INFO] [1624187301.503175]: Nothing is detected
# [INFO] [1624187301.787397]: Nothing is detected
# [INFO] [1624187302.013725]: Nothing is detected
# [INFO] [1624187302.278702]: Nothing is detected
# [INFO] [1624187302.509401]: Nothing is detected
# [INFO] [1624187302.793916]: Nothing is detected
# [INFO] [1624187303.192515]: Nothing is detected
# [INFO] [1624187303.500553]: Nothing is detected
# [INFO] [1624187303.759715]: Nothing is detected
# [INFO] [1624187304.050716]: Nothing is detected
# [INFO] [1624187304.303557]: Nothing is detected
# [INFO] [1624187304.648753]: Nothing is detected
# [INFO] [1624187305.015353]: Nothing is detected
# [INFO] [1624187305.281092]: Nothing is detected
# [INFO] [1624187305.536979]: Nothing is detected
# [INFO] [1624187305.798406]: Nothing is detected
# [INFO] [1624187306.079148]: Nothing is detected
# [INFO] [1624187306.390669]: Nothing is detected
# [INFO] [1624187306.713825]: Nothing is detected
# [INFO] [1624187306.971574]: Nothing is detected
# [INFO] [1624187307.236066]: Nothing is detected
# [INFO] [1624187307.536348]: Nothing is detected
# [INFO] [1624187307.856720]: Nothing is detected
# [INFO] [1624187308.188704]: Nothing is detected
# [INFO] [1624187308.478660]: Nothing is detected
# [INFO] [1624187308.719363]: Nothing is detected
# [INFO] [1624187308.967561]: Nothing is detected
# [INFO] [1624187309.247412]: Nothing is detected
# [INFO] [1624187309.533519]: Nothing is detected
# [INFO] [1624187309.862734]: Nothing is detected
# [INFO] [1624187310.184785]: Nothing is detected
# [INFO] [1624187310.429419]: Nothing is detected
# [INFO] [1624187310.672833]: Nothing is detected
# [INFO] [1624187310.935076]: Nothing is detected
# [INFO] [1624187311.244246]: Nothing is detected
# [INFO] [1624187311.613629]: Nothing is detected
# [INFO] [1624187311.858901]: Nothing is detected
# [INFO] [1624187312.140892]: Nothing is detected
# [INFO] [1624187312.397449]: Nothing is detected
# [INFO] [1624187312.649639]: Nothing is detected
# [INFO] [1624187313.030756]: Nothing is detected
# [INFO] [1624187313.344230]: Nothing is detected
# [INFO] [1624187313.615371]: Nothing is detected
# [INFO] [1624187313.867559]: Nothing is detected
# [INFO] [1624187314.111741]: Nothing is detected
# [INFO] [1624187314.409528]: Nothing is detected
# [INFO] [1624187314.757197]: Nothing is detected
# [INFO] [1624187315.013423]: Nothing is detected
# [INFO] [1624187315.277277]: Nothing is detected
# [INFO] [1624187315.550679]: Nothing is detected
# [INFO] [1624187315.812753]: Nothing is detected
# [INFO] [1624187316.092638]: Nothing is detected
# [INFO] [1624187316.404814]: Nothing is detected
# [INFO] [1624187316.742188]: Nothing is detected
# [INFO] [1624187316.994812]: Nothing is detected
# [INFO] [1624187317.283481]: Nothing is detected
# [INFO] [1624187317.534226]: Nothing is detected
# [INFO] [1624187317.914830]: Nothing is detected
# [INFO] [1624187318.296481]: Nothing is detected
# [INFO] [1624187318.580828]: Nothing is detected
# [INFO] [1624187318.822038]: Nothing is detected
# [INFO] [1624187319.082133]: Nothing is detected
# [INFO] [1624187319.363142]: Nothing is detected
# [INFO] [1624187319.687910]: Nothing is detected
# [INFO] [1624187320.065654]: Nothing is detected
# [INFO] [1624187320.330916]: Nothing is detected
# [INFO] [1624187320.597408]: Nothing is detected
# [INFO] [1624187320.862686]: Nothing is detected
# [INFO] [1624187321.167688]: Nothing is detected
# [INFO] [1624187321.529928]: Nothing is detected
# [INFO] [1624187321.837419]: Nothing is detected
# [INFO] [1624187322.087177]: Nothing is detected
# [INFO] [1624187322.312760]: Nothing is detected
# [INFO] [1624187322.555441]: Nothing is detected
# [INFO] [1624187322.846914]: Nothing is detected
# [INFO] [1624187323.194227]: Nothing is detected
# [INFO] [1624187323.540064]: Nothing is detected
# [INFO] [1624187323.804852]: Nothing is detected
# [INFO] [1624187324.061255]: Nothing is detected
# [INFO] [1624187324.303292]: Nothing is detected
# [INFO] [1624187324.560991]: Nothing is detected
